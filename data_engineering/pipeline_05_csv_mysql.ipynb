# %%
import pymysql
import pandas as pd
import pymysql.cursors
from sqlalchemy import create_engine
import numpy as np
from dotenv import load_dotenv, dotenv_values

# %%
try:
    mysql_key_dict = dotenv_values("api_keys/mysql_key.env")
    mysql_key =mysql_key_dict["mysql_key"]
except:
    mysql_key = ""

# %% [markdown]
# # Functions

# %%
def transform_csv(x_in):
    """
    Function to transform csv
    :param x_in:
    :return x_out:
    """
    try:
        x_out = x_in[-10:]
    except:
        x_out = ''
    return x_out

# %% [markdown]
# # Pipeline

# %%
# Crear un DataFrame con los resultados de la consulta
try:
    df = pd.read_csv('data/out_001134.csv',sep=",", encoding='utf-8')
except:
    df = pd.read_csv('data/out_001134.csv',sep=",", encoding='latin1')

# %%
# df['Tipo'] = df['Tipo'].replace(np.nan, '')
df['Contenido'] = df['Contenido'].replace(np.nan, '')
df['url_codigo'] = df['url'].apply(lambda x: transform_csv(x))
df = df.rename(columns={"Grupo Parlamentario": "Grupo_Parlamentario"})

# %%
#Introducir aquí la propia contraseña detas
contraseña = mysql_key
engine = create_engine(f'''mysql+pymysql://root:{contraseña}@localhost/congreso_diputados''')

# %%
# Connect to the database

try:
    # Convertir el DataFrame a una tabla en la base de datos
    df.to_sql(name='congreso_preguntas_12_21_27_10_2024', con=engine, if_exists='replace', index=False)
    print("DataFrame convertido a tabla en la base de datos.")
except:
    print("No se pudo completar la conexión")
    
# finally:
#     # Cerrar la conexión
#     con.close()
# Out:
# DataFrame convertido a tabla en la base de datos.

# %% [markdown]
# # Show Dataframe

# %%
df.head(10)
# Out:
#   Institucion  Legislatura  Expediente  Presentada  Calificada  \
# 0    Congreso           15  184/000001  03/12/2019  13/12/2019
# 1    Congreso           15  184/000002  03/12/2019  13/12/2019
# 2    Congreso           15  184/000003  03/12/2019  13/12/2019
# 3    Congreso           15  184/000004  03/12/2019  13/12/2019
# 4    Congreso           15  184/000005  03/12/2019  13/12/2019
# 5    Congreso           15  184/000006  03/12/2019  13/12/2019
# 6    Congreso           15  184/000007  03/12/2019  13/12/2019
# 7    Congreso           15  184/000008  04/12/2019  13/12/2019
# 8    Congreso           15  184/000009  04/12/2019  13/12/2019
# 9    Congreso           15  184/000010  04/12/2019  13/12/2019
#
#                                            Contenido  \
# 0  Discriminación de Asturias en la construcción ...
# 1  Motivos del desinterés del Gobierno por la mej...
# 2  Previsiones acerca de dotar a los consumidores...
# 3  Medidas previstas para resolver el problema de...
# ...
